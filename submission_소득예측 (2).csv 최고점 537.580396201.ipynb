# %% [markdown]
# #CatBoost + Optuna + StratifiedKFold

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install optuna
# !pip install category_encoders
# !pip install catboost

# %%
#라이브러리 임포트
import os
import random
import numpy as np
import pandas as pd
import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import mean_squared_error
from category_encoders import TargetEncoder
from catboost import CatBoostRegressor
# warning 제거
import warnings
warnings.filterwarnings("ignore")

# Reproducibility setup
RANDOM_SEED = 42
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
train_data = pd.read_csv('/content/drive/MyDrive/소득 예측/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/소득 예측/test.csv')

# %%
# id 제거
train_data.drop('ID', axis=1, inplace=True)
test_data.drop('ID', axis=1, inplace=True)

# %%
# x,y 분리
X_train = train_data.drop('Income', axis=1)
Y_train = train_data['Income']

# %%
# 근무 시간 유형 정의 함수
def define_work_type(weeks):
    if weeks < 52:
        return '비정규직'
    else:
        return '정규직'

# 근무 시간 유형 적용
X_train['Work_Type'] = X_train['Working_Week (Yearly)'].apply(define_work_type)
test_data['Work_Type'] = test_data['Working_Week (Yearly)'].apply(define_work_type)

# 근무 시간 유형과 직업 상태 결합
X_train['Work_Type_Occupation'] = X_train['Work_Type'] + '_' + X_train['Occupation_Status']
test_data['Work_Type_Occupation'] = test_data['Work_Type'] + '_' + test_data['Occupation_Status']

# feature importance 높은 2개 결합
X_train['Occupation_Industry'] = X_train['Occupation_Status'] + "_" + X_train['Industry_Status']
test_data['Occupation_Industry'] = test_data['Occupation_Status'] + "_" + test_data['Industry_Status']

# 로그 변환 (0인 경우를 고려해 1을 더한 후 로그 적용)
X_train['Log_Dividends'] = np.log1p(X_train['Dividends'])
test_data['Log_Dividends'] = np.log1p(test_data['Dividends'])

X_train['Log_Gains'] = np.log1p(X_train['Gains'])
test_data['Log_Gains'] = np.log1p(test_data['Gains'])

X_train['Log_Losses'] = np.log1p(X_train['Losses'])
test_data['Log_Losses'] = np.log1p(test_data['Losses'])

# 중복, 필요없는 column 제거
# summary는 다중공선성 때문에 제거
X_train.drop(['Dividends', 'Household_Summary', 'Gains', 'Losses', 'Work_Type', 'Working_Week (Yearly)'], axis=1, inplace=True)
test_data.drop(['Dividends', 'Household_Summary','Gains', 'Losses', 'Work_Type', 'Working_Week (Yearly)'], axis=1, inplace=True)

# %%
# 숫자형(Integer), 범주형(Categorical) 변수 분할
numerical_list=[]
categorical_list=[]

for i in X_train.columns :
  if X_train[i].dtypes == 'O' :
    categorical_list.append(i)
  else :
    numerical_list.append(i)

print("categorical_list :", categorical_list)
print("numerical_list :", numerical_list)
# Out:
# categorical_list : ['Gender', 'Education_Status', 'Employment_Status', 'Industry_Status', 'Occupation_Status', 'Race', 'Hispanic_Origin', 'Martial_Status', 'Household_Status', 'Citizenship', 'Birth_Country', 'Birth_Country (Father)', 'Birth_Country (Mother)', 'Tax_Status', 'Income_Status', 'Work_Type_Occupation', 'Occupation_Industry']
# numerical_list : ['Age', 'Log_Dividends', 'Log_Gains', 'Log_Losses']

# %%
# 타겟 인코딩
encoder = TargetEncoder(cols=categorical_list)
X_train = encoder.fit_transform(X_train, Y_train)
test_data = encoder.transform(test_data)

# %%
def objective(trial):
    # hyperparameter space 정의
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
        'loss_function': 'RMSE',
        'eval_metric': 'RMSE',
        'bootstrap_type': 'Bernoulli',
        'subsample': trial.suggest_uniform('subsample', 0.4, 1.0),
        'random_strength': trial.suggest_uniform('random_strength', 1e-9, 10),
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations', 1, 10),
        'logging_level': 'Silent',
        'random_seed': RANDOM_SEED
    }

    # Stratified K-Fold 교차 검증
    n_splits = 5
    cv_scores = np.zeros(n_splits)
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_SEED)

    for idx, (train_index, valid_index) in enumerate(kf.split(X_train, Y_train)):
        X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[valid_index]
        Y_train_fold, Y_valid_fold = Y_train.iloc[train_index], Y_train.iloc[valid_index]

        model = CatBoostRegressor(**params)
        model.fit(X_train_fold, Y_train_fold, eval_set=[(X_valid_fold, Y_valid_fold)], verbose=0)

        preds = model.predict(X_valid_fold)

        # Replace negative predictions with zero before calculating RMSE
        preds_adjusted = np.maximum(0, preds)

        cv_scores[idx] = np.sqrt(mean_squared_error(Y_valid_fold, preds_adjusted))

    return np.mean(cv_scores)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED))
study.optimize(objective, n_trials=100)

print(f"Best trial: {study.best_trial.params}")
# Out:
# [I 2024-03-11 13:54:36,276] A new study created in memory with name: no-name-fd34f52c-43d9-4947-bff0-4c5300265d67
# [I 2024-03-11 13:55:30,384] Trial 0 finished with value: 590.5191194019231 and parameters: {'iterations': 437, 'depth': 10, 'learning_rate': 0.22227824312530747, 'l2_leaf_reg': 0.0024430162614261413, 'subsample': 0.4936111842654619, 'random_strength': 1.559945204206032, 'leaf_estimation_iterations': 1}. Best is trial 0 with value: 590.5191194019231.
# [I 2024-03-11 13:56:19,167] Trial 1 finished with value: 589.4299469101275 and parameters: {'iterations': 880, 'depth': 8, 'learning_rate': 0.21534104756085318, 'l2_leaf_reg': 1.5320059381854043e-08, 'subsample': 0.9819459112971965, 'random_strength': 8.324426408171774, 'leaf_estimation_iterations': 3}. Best is trial 1 with value: 589.4299469101275.
# [I 2024-03-11 13:56:27,325] Trial 2 finished with value: 588.0829975316351 and parameters: {'iterations': 263, 'depth': 5, 'learning_rate': 0.09823025045826593, 'l2_leaf_reg': 0.00052821153945323, 'subsample': 0.6591670111852694, 'random_strength': 2.91229140268919, 'leaf_estimation_iterations': 7}. Best is trial 2 with value: 588.0829975316351.
# [I 2024-03-11 13:56:34,727] Trial 3 finished with value: 589.3304260288895 and parameters: {'iterations': 225, 'depth': 6, 'learning_rate': 0.11624493455517058, 'l2_leaf_reg': 0.00012724181576752517, 'subsample': 0.8711055768358081, 'random_strength': 1.9967378223839236, 'leaf_estimation_iterations': 6}. Best is trial 2 with value: 588.0829975316351.
# [I 2024-03-11 13:56:48,287] Trial 4 finished with value: 590.5419880430263 and parameters: {'iterations': 633, 'depth': 4, 'learning_rate': 0.1861880070514171, 'l2_leaf_reg': 3.425445902633376e-07, 'subsample': 0.43903095579116774, 'random_strength': 9.488855372584448, 'leaf_estimation_iterations': 10}. Best is trial 2 with value: 588.0829975316351.
# [I 2024-03-11 13:57:13,781] Trial 5 finished with value: 588.0135628022668 and parameters: {'iterations': 828, 'depth': 6, 'learning_rate': 0.03832491306185132, 'l2_leaf_reg': 0.014391207615728067, 'subsample': 0.6640914962437607, 'random_strength': 1.2203823493257502, 'leaf_estimation_iterations': 5}. Best is trial 5 with value: 588.0135628022668.
# [I 2024-03-11 13:57:33,725] Trial 6 finished with value: 587.9312574833158 and parameters: {'iterations': 130, 'depth': 10, 'learning_rate': 0.0850461946640049, 'l2_leaf_reg': 0.009176996354542699, 'subsample': 0.5870266456536466, 'random_strength': 5.20068021225804, 'leaf_estimation_iterations': 6}. Best is trial 6 with value: 587.9312574833158.
# [I 2024-03-11 13:58:31,974] Trial 7 finished with value: 591.2546746068043 and parameters: {'iterations': 266, 'depth': 10, 'learning_rate': 0.2347885187747232, 'l2_leaf_reg': 2.854239907497756, 'subsample': 0.9368964102565893, 'random_strength': 5.978999788512952, 'leaf_estimation_iterations': 10}. Best is trial 6 with value: 587.9312574833158.
# [I 2024-03-11 13:58:36,227] Trial 8 finished with value: 590.1610597474407 and parameters: {'iterations': 179, 'depth': 5, 'learning_rate': 0.023115913784056037, 'l2_leaf_reg': 8.471746987003668e-06, 'subsample': 0.6332063738136893, 'random_strength': 2.7134903184676102, 'leaf_estimation_iterations': 9}. Best is trial 6 with value: 587.9312574833158.
# [I 2024-03-11 13:58:48,899] Trial 9 finished with value: 589.8838562244225 and parameters: {'iterations': 421, 'depth': 5, 'learning_rate': 0.16738186411589207, 'l2_leaf_reg': 1.8548894229694903e-07, 'subsample': 0.8813181884524238, 'random_strength': 0.7455064377231575, 'leaf_estimation_iterations': 10}. Best is trial 6 with value: 587.9312574833158.
# [I 2024-03-11 13:59:21,159] Trial 10 finished with value: 590.7898893494563 and parameters: {'iterations': 562, 'depth': 8, 'learning_rate': 0.291165762128481, 'l2_leaf_reg': 0.6830346849054016, 'subsample': 0.5636121263206507, 'random_strength': 5.409439082214534, 'leaf_estimation_iterations': 4}. Best is trial 6 with value: 587.9312574833158.
# [I 2024-03-11 14:00:04,912] Trial 11 finished with value: 587.0204272812808 and parameters: {'iterations': 977, 'depth': 7, 'learning_rate': 0.020570021111311926, 'l2_leaf_reg': 0.0292027290697688, 'subsample': 0.7591712253366455, 'random_strength': 4.388322193385123, 'leaf_estimation_iterations': 7}. Best is trial 11 with value: 587.0204272812808.
# [I 2024-03-11 14:01:06,217] Trial 12 finished with value: 587.4572979789879 and parameters: {'iterations': 963, 'depth': 8, 'learning_rate': 0.0711561210316835, 'l2_leaf_reg': 0.08091338977411727, 'subsample': 0.7824697944253278, 'random_strength': 3.8759420412520136, 'leaf_estimation_iterations': 7}. Best is trial 11 with value: 587.0204272812808.
# [I 2024-03-11 14:02:15,634] Trial 13 finished with value: 587.9770798294127 and parameters: {'iterations': 1000, 'depth': 8, 'learning_rate': 0.07123359032863376, 'l2_leaf_reg': 0.19390559424037496, 'subsample': 0.7953886449606391, 'random_strength': 4.036796945138106, 'leaf_estimation_iterations': 8}. Best is trial 11 with value: 587.0204272812808.
# [I 2024-03-11 14:02:51,290] Trial 14 finished with value: 586.7751432651439 and parameters: {'iterations': 767, 'depth': 7, 'learning_rate': 0.011200115050089963, 'l2_leaf_reg': 0.084327006734949, 'subsample': 0.7670123107707054, 'random_strength': 6.634064286456419, 'leaf_estimation_iterations': 8}. Best is trial 14 with value: 586.7751432651439.
# [I 2024-03-11 14:03:24,026] Trial 15 finished with value: 586.7203821317905 and parameters: {'iterations': 723, 'depth': 7, 'learning_rate': 0.011928242634860722, 'l2_leaf_reg': 7.830509570792111, 'subsample': 0.7760737303687472, 'random_strength': 6.926302990238892, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:03:59,632] Trial 16 finished with value: 588.023890718114 and parameters: {'iterations': 716, 'depth': 7, 'learning_rate': 0.1411746307345064, 'l2_leaf_reg': 6.9411010659485886, 'subsample': 0.7477396296796389, 'random_strength': 6.992972543849235, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:05:18,447] Trial 17 finished with value: 587.0878674303292 and parameters: {'iterations': 744, 'depth': 9, 'learning_rate': 0.04582502633673068, 'l2_leaf_reg': 9.654581076370702, 'subsample': 0.8342639231190585, 'random_strength': 7.124770030022391, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:05:47,449] Trial 18 finished with value: 587.7145741900438 and parameters: {'iterations': 712, 'depth': 6, 'learning_rate': 0.011114257589881616, 'l2_leaf_reg': 0.545567984517963, 'subsample': 0.7104882995181058, 'random_strength': 7.071944785956315, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:06:21,948] Trial 19 finished with value: 588.459632515104 and parameters: {'iterations': 800, 'depth': 7, 'learning_rate': 0.12835925014510385, 'l2_leaf_reg': 3.8648569946538525e-05, 'subsample': 0.9177448847702903, 'random_strength': 9.966892542717108, 'leaf_estimation_iterations': 4}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:07:29,064] Trial 20 finished with value: 587.6459587861043 and parameters: {'iterations': 616, 'depth': 9, 'learning_rate': 0.06933166947726195, 'l2_leaf_reg': 1.4619315692808055, 'subsample': 0.7068812975401211, 'random_strength': 8.112070474873882, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:08:10,317] Trial 21 finished with value: 587.2722363279568 and parameters: {'iterations': 927, 'depth': 7, 'learning_rate': 0.04614561798057032, 'l2_leaf_reg': 0.03757671025959004, 'subsample': 0.77686035291479, 'random_strength': 4.29027901407157, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:08:47,021] Trial 22 finished with value: 587.0230416440953 and parameters: {'iterations': 873, 'depth': 7, 'learning_rate': 0.012232913548831265, 'l2_leaf_reg': 0.002027044231984793, 'subsample': 0.8189355351369199, 'random_strength': 6.287039923634527, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:09:03,678] Trial 23 finished with value: 587.0645543066728 and parameters: {'iterations': 453, 'depth': 6, 'learning_rate': 0.04241138553473299, 'l2_leaf_reg': 0.21057050177070352, 'subsample': 0.7328314294488825, 'random_strength': 8.141744955737314, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:10:18,598] Trial 24 finished with value: 587.3767425556025 and parameters: {'iterations': 788, 'depth': 9, 'learning_rate': 0.0369849957582493, 'l2_leaf_reg': 0.011559425598458557, 'subsample': 0.8417758527931649, 'random_strength': 5.873035895748133, 'leaf_estimation_iterations': 5}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:10:46,444] Trial 25 finished with value: 587.2363754436248 and parameters: {'iterations': 637, 'depth': 7, 'learning_rate': 0.011568057342073862, 'l2_leaf_reg': 0.08085730256313865, 'subsample': 0.7549321800329315, 'random_strength': 4.807663692825934, 'leaf_estimation_iterations': 6}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:11:17,947] Trial 26 finished with value: 587.9806612397776 and parameters: {'iterations': 902, 'depth': 6, 'learning_rate': 0.10188221126471068, 'l2_leaf_reg': 0.0013473192534751142, 'subsample': 0.6163867144768023, 'random_strength': 6.535005330972073, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:12:01,771] Trial 27 finished with value: 587.7560284169306 and parameters: {'iterations': 682, 'depth': 8, 'learning_rate': 0.06613480819543305, 'l2_leaf_reg': 1.8442531550406964, 'subsample': 0.6758635661642637, 'random_strength': 7.573147661676292, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:12:26,842] Trial 28 finished with value: 590.5766898268969 and parameters: {'iterations': 516, 'depth': 7, 'learning_rate': 0.2906484427719832, 'l2_leaf_reg': 0.32941320920409817, 'subsample': 0.8827667905624843, 'random_strength': 9.09061777979113, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:12:43,428] Trial 29 finished with value: 588.7221048088628 and parameters: {'iterations': 834, 'depth': 4, 'learning_rate': 0.02741862064150039, 'l2_leaf_reg': 0.007251062786726688, 'subsample': 0.47405255507186395, 'random_strength': 3.5127862028518613, 'leaf_estimation_iterations': 6}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:12:59,653] Trial 30 finished with value: 589.4059862257917 and parameters: {'iterations': 765, 'depth': 6, 'learning_rate': 0.06065526500853938, 'l2_leaf_reg': 0.04047753829541278, 'subsample': 0.5152069037458851, 'random_strength': 0.0026211240468656527, 'leaf_estimation_iterations': 1}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:13:36,250] Trial 31 finished with value: 587.128245588175 and parameters: {'iterations': 870, 'depth': 7, 'learning_rate': 0.01812140521860646, 'l2_leaf_reg': 0.0028729038246020568, 'subsample': 0.8164572011917741, 'random_strength': 6.516572924696279, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:14:16,838] Trial 32 finished with value: 586.9017087367171 and parameters: {'iterations': 940, 'depth': 7, 'learning_rate': 0.011411141345782182, 'l2_leaf_reg': 0.0006140766880230587, 'subsample': 0.8148527251280432, 'random_strength': 4.722440435261316, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:15:13,847] Trial 33 finished with value: 587.0700639038298 and parameters: {'iterations': 947, 'depth': 8, 'learning_rate': 0.032194927308224396, 'l2_leaf_reg': 0.00026153979847117365, 'subsample': 0.9679251695466697, 'random_strength': 4.571091340955674, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:15:54,481] Trial 34 finished with value: 587.7410670276569 and parameters: {'iterations': 984, 'depth': 7, 'learning_rate': 0.05441834243396229, 'l2_leaf_reg': 1.123764094164231e-05, 'subsample': 0.7245686741004405, 'random_strength': 5.487252824453014, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:16:46,017] Trial 35 finished with value: 588.2945585357523 and parameters: {'iterations': 904, 'depth': 8, 'learning_rate': 0.08757818774962599, 'l2_leaf_reg': 8.522686077996937e-05, 'subsample': 0.8540919554819031, 'random_strength': 2.9806236782757143, 'leaf_estimation_iterations': 6}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:17:08,284] Trial 36 finished with value: 589.2058996675071 and parameters: {'iterations': 839, 'depth': 5, 'learning_rate': 0.20966548730617748, 'l2_leaf_reg': 0.000565685560782087, 'subsample': 0.7835640481130487, 'random_strength': 8.711869443466192, 'leaf_estimation_iterations': 5}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:17:36,880] Trial 37 finished with value: 587.6068377761287 and parameters: {'iterations': 932, 'depth': 6, 'learning_rate': 0.02995638383712304, 'l2_leaf_reg': 1.7770130114073963e-06, 'subsample': 0.6819025402979935, 'random_strength': 2.09603197793163, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:18:06,687] Trial 38 finished with value: 587.5470749358306 and parameters: {'iterations': 661, 'depth': 7, 'learning_rate': 0.10793191879943127, 'l2_leaf_reg': 0.0006647971439755275, 'subsample': 0.7556811554869644, 'random_strength': 4.952275244997611, 'leaf_estimation_iterations': 6}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:18:25,717] Trial 39 finished with value: 587.5292324768131 and parameters: {'iterations': 587, 'depth': 6, 'learning_rate': 0.08547714717662244, 'l2_leaf_reg': 0.004530187096366313, 'subsample': 0.917219569072593, 'random_strength': 7.605999603957774, 'leaf_estimation_iterations': 2}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:18:59,480] Trial 40 finished with value: 587.6425217173576 and parameters: {'iterations': 366, 'depth': 9, 'learning_rate': 0.05414302216868415, 'l2_leaf_reg': 0.046216070011945345, 'subsample': 0.652841715978702, 'random_strength': 5.713869782679102, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:19:37,568] Trial 41 finished with value: 586.866107520468 and parameters: {'iterations': 873, 'depth': 7, 'learning_rate': 0.014866863468748166, 'l2_leaf_reg': 0.01738355976089344, 'subsample': 0.8317195803974173, 'random_strength': 6.539026599817058, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:20:15,603] Trial 42 finished with value: 587.1684273430993 and parameters: {'iterations': 854, 'depth': 7, 'learning_rate': 0.025439460741086502, 'l2_leaf_reg': 0.01637527771018306, 'subsample': 0.8101545730152236, 'random_strength': 6.191282812161358, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:21:04,070] Trial 43 finished with value: 587.1170842221406 and parameters: {'iterations': 810, 'depth': 8, 'learning_rate': 0.011415825821741572, 'l2_leaf_reg': 0.019780826329393094, 'subsample': 0.8959591411562021, 'random_strength': 3.3914556919780567, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 586.7203821317905.
# [I 2024-03-11 14:21:42,488] Trial 44 finished with value: 586.3766679393003 and parameters: {'iterations': 749, 'depth': 7, 'learning_rate': 0.035345223562561576, 'l2_leaf_reg': 0.10013281114432723, 'subsample': 0.8456629644337861, 'random_strength': 7.639385957348795, 'leaf_estimation_iterations': 10}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:22:10,838] Trial 45 finished with value: 587.5948708596683 and parameters: {'iterations': 744, 'depth': 6, 'learning_rate': 0.03919633336886228, 'l2_leaf_reg': 3.6952317334888303, 'subsample': 0.402441539451348, 'random_strength': 7.773340989277127, 'leaf_estimation_iterations': 10}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:22:52,830] Trial 46 finished with value: 591.2403678875261 and parameters: {'iterations': 696, 'depth': 8, 'learning_rate': 0.26869647668365915, 'l2_leaf_reg': 2.407838506084373e-08, 'subsample': 0.8534334217347719, 'random_strength': 6.880121710011874, 'leaf_estimation_iterations': 10}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:23:32,472] Trial 47 finished with value: 588.3350703426931 and parameters: {'iterations': 767, 'depth': 7, 'learning_rate': 0.17530581454691696, 'l2_leaf_reg': 0.119113210708895, 'subsample': 0.8633286778751916, 'random_strength': 8.460935796534763, 'leaf_estimation_iterations': 9}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:24:26,429] Trial 48 finished with value: 587.1337684303095 and parameters: {'iterations': 735, 'depth': 8, 'learning_rate': 0.05018481140412163, 'l2_leaf_reg': 0.3958428583690011, 'subsample': 0.9610992038920515, 'random_strength': 6.70035831857612, 'leaf_estimation_iterations': 10}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:24:57,620] Trial 49 finished with value: 587.319618765135 and parameters: {'iterations': 811, 'depth': 6, 'learning_rate': 0.02336085103477676, 'l2_leaf_reg': 1.6587618729690914, 'subsample': 0.805082610472599, 'random_strength': 7.351703427930503, 'leaf_estimation_iterations': 9}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:25:27,267] Trial 50 finished with value: 587.1901268033769 and parameters: {'iterations': 894, 'depth': 5, 'learning_rate': 0.03298001382853098, 'l2_leaf_reg': 1.0188686127462865, 'subsample': 0.9021544984779143, 'random_strength': 5.471215484632303, 'leaf_estimation_iterations': 8}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:26:12,394] Trial 51 finished with value: 586.8047004254853 and parameters: {'iterations': 975, 'depth': 7, 'learning_rate': 0.022092471302662283, 'l2_leaf_reg': 0.028822142123314808, 'subsample': 0.7702303521676387, 'random_strength': 5.1472034396452, 'leaf_estimation_iterations': 6}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:26:51,613] Trial 52 finished with value: 586.8029961528862 and parameters: {'iterations': 955, 'depth': 7, 'learning_rate': 0.018225867886584694, 'l2_leaf_reg': 0.00614588343413891, 'subsample': 0.8295866809933174, 'random_strength': 5.039113495316087, 'leaf_estimation_iterations': 5}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:27:31,104] Trial 53 finished with value: 587.3288893850216 and parameters: {'iterations': 975, 'depth': 7, 'learning_rate': 0.02603983399306998, 'l2_leaf_reg': 0.005889555798296922, 'subsample': 0.7747702412559355, 'random_strength': 5.144504260668174, 'leaf_estimation_iterations': 5}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:28:23,371] Trial 54 finished with value: 587.6610399164704 and parameters: {'iterations': 909, 'depth': 8, 'learning_rate': 0.07786866245169202, 'l2_leaf_reg': 0.13497937064749682, 'subsample': 0.8319936050580612, 'random_strength': 6.016346620046937, 'leaf_estimation_iterations': 4}. Best is trial 44 with value: 586.3766679393003.
# [I 2024-03-11 14:29:05,537] Trial 55 finished with value: 586.2816845971208 and parameters: {'iterations': 999, 'depth': 7, 'learning_rate': 0.04111693621124347, 'l2_leaf_reg': 4.10350918064421, 'subsample': 0.7370072428802986, 'random_strength': 7.126652013395121, 'leaf_estimation_iterations': 5}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:29:36,839] Trial 56 finished with value: 586.6634937779858 and parameters: {'iterations': 995, 'depth': 6, 'learning_rate': 0.045058670425345504, 'l2_leaf_reg': 4.997738179274515, 'subsample': 0.6987608069768753, 'random_strength': 7.942238169778794, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:29:54,268] Trial 57 finished with value: 586.5377859532721 and parameters: {'iterations': 520, 'depth': 6, 'learning_rate': 0.05993881522628583, 'l2_leaf_reg': 4.811384982682696, 'subsample': 0.735019922993412, 'random_strength': 7.904838415830751, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:30:09,725] Trial 58 finished with value: 588.3105405745384 and parameters: {'iterations': 498, 'depth': 6, 'learning_rate': 0.13040964180042197, 'l2_leaf_reg': 6.924078004534491, 'subsample': 0.6892802353424154, 'random_strength': 8.916693545912768, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:30:23,402] Trial 59 finished with value: 587.8971704070098 and parameters: {'iterations': 549, 'depth': 5, 'learning_rate': 0.06082209615232234, 'l2_leaf_reg': 4.362112079462977, 'subsample': 0.7311327099177268, 'random_strength': 7.964312391023174, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:30:32,678] Trial 60 finished with value: 587.3101254784765 and parameters: {'iterations': 310, 'depth': 6, 'learning_rate': 0.0452653506594058, 'l2_leaf_reg': 0.8118883027284746, 'subsample': 0.6156236607497272, 'random_strength': 9.603641777524908, 'leaf_estimation_iterations': 2}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:30:56,411] Trial 61 finished with value: 587.9648477069547 and parameters: {'iterations': 997, 'depth': 5, 'learning_rate': 0.04172151541477114, 'l2_leaf_reg': 2.7177349157633333, 'subsample': 0.7087648806345735, 'random_strength': 7.291771806105093, 'leaf_estimation_iterations': 4}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:31:07,998] Trial 62 finished with value: 586.8724464205566 and parameters: {'iterations': 426, 'depth': 6, 'learning_rate': 0.05986163439965217, 'l2_leaf_reg': 9.64280350536642, 'subsample': 0.7407784224104594, 'random_strength': 8.360970131754627, 'leaf_estimation_iterations': 2}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:31:32,153] Trial 63 finished with value: 588.2497986607052 and parameters: {'iterations': 600, 'depth': 7, 'learning_rate': 0.07855214512974376, 'l2_leaf_reg': 0.3308179062044644, 'subsample': 0.7938209661857288, 'random_strength': 7.554534807356718, 'leaf_estimation_iterations': 4}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:31:49,868] Trial 64 finished with value: 586.5516223861885 and parameters: {'iterations': 660, 'depth': 6, 'learning_rate': 0.03937489710813756, 'l2_leaf_reg': 5.002687485203519, 'subsample': 0.6535037330192395, 'random_strength': 7.023326337087082, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:32:09,312] Trial 65 finished with value: 586.8280036588801 and parameters: {'iterations': 636, 'depth': 6, 'learning_rate': 0.03811571350216454, 'l2_leaf_reg': 4.41947663642017, 'subsample': 0.6581509238651032, 'random_strength': 7.071105970118209, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:32:24,577] Trial 66 finished with value: 587.873245536525 and parameters: {'iterations': 663, 'depth': 5, 'learning_rate': 0.04964650621782726, 'l2_leaf_reg': 1.262976350786187, 'subsample': 0.6431035014354457, 'random_strength': 7.880804153227308, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:32:37,859] Trial 67 finished with value: 587.7130597723306 and parameters: {'iterations': 563, 'depth': 6, 'learning_rate': 0.09735136980081369, 'l2_leaf_reg': 0.5919792259893034, 'subsample': 0.6159646159237439, 'random_strength': 9.221288932906822, 'leaf_estimation_iterations': 1}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:32:44,873] Trial 68 finished with value: 588.2850395810929 and parameters: {'iterations': 485, 'depth': 4, 'learning_rate': 0.0721286343332407, 'l2_leaf_reg': 2.2097243475246278, 'subsample': 0.5564710638139618, 'random_strength': 8.499133250872397, 'leaf_estimation_iterations': 2}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:33:09,227] Trial 69 finished with value: 586.9573912311874 and parameters: {'iterations': 776, 'depth': 6, 'learning_rate': 0.035144544803847454, 'l2_leaf_reg': 6.385246262250734, 'subsample': 0.6972392953611168, 'random_strength': 8.12772233428856, 'leaf_estimation_iterations': 4}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:33:35,669] Trial 70 finished with value: 587.1304941707838 and parameters: {'iterations': 707, 'depth': 7, 'learning_rate': 0.061008281174326884, 'l2_leaf_reg': 3.287674027615875, 'subsample': 0.7196644758107813, 'random_strength': 6.8396621227318635, 'leaf_estimation_iterations': 3}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:34:17,899] Trial 71 finished with value: 586.8880235742757 and parameters: {'iterations': 949, 'depth': 7, 'learning_rate': 0.028996330039783677, 'l2_leaf_reg': 0.9066253819141772, 'subsample': 0.6706967165563192, 'random_strength': 7.288951211230936, 'leaf_estimation_iterations': 5}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:34:46,250] Trial 72 finished with value: 587.3735213045219 and parameters: {'iterations': 737, 'depth': 7, 'learning_rate': 0.01971261310529586, 'l2_leaf_reg': 0.251586157898001, 'subsample': 0.747976550689162, 'random_strength': 6.276569771065249, 'leaf_estimation_iterations': 4}. Best is trial 55 with value: 586.2816845971208.
# [I 2024-03-11 14:35:15,058] Trial 73 finished with value: 585.9777709307356 and parameters: {'iterations': 672, 'depth': 7, 'learning_rate': 0.046529712946261424, 'l2_leaf_reg': 9.574797969466443, 'subsample': 0.7926385529402424, 'random_strength': 7.533051445020369, 'leaf_estimation_iterations': 5}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:35:30,241] Trial 74 finished with value: 586.4527733755585 and parameters: {'iterations': 534, 'depth': 6, 'learning_rate': 0.05439314467009473, 'l2_leaf_reg': 9.037641738182058, 'subsample': 0.7664612782414018, 'random_strength': 7.500667038922802, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:35:46,626] Trial 75 finished with value: 586.824776623854 and parameters: {'iterations': 544, 'depth': 6, 'learning_rate': 0.05441510184835184, 'l2_leaf_reg': 8.951698857437496, 'subsample': 0.7860935696070714, 'random_strength': 8.704459904008091, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:35:57,000] Trial 76 finished with value: 586.7816447746384 and parameters: {'iterations': 383, 'depth': 6, 'learning_rate': 0.06717565222190058, 'l2_leaf_reg': 4.9096296693011645, 'subsample': 0.7603708201140288, 'random_strength': 7.709181460239028, 'leaf_estimation_iterations': 3}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:36:08,050] Trial 77 finished with value: 586.8167487026396 and parameters: {'iterations': 464, 'depth': 6, 'learning_rate': 0.0455547972762887, 'l2_leaf_reg': 2.085861039923914, 'subsample': 0.5905125890045977, 'random_strength': 7.469952532222067, 'leaf_estimation_iterations': 1}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:36:21,253] Trial 78 finished with value: 588.9959628299872 and parameters: {'iterations': 582, 'depth': 5, 'learning_rate': 0.15057021122066133, 'l2_leaf_reg': 3.018062314282766, 'subsample': 0.7184485880728797, 'random_strength': 8.236621330943901, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:36:41,655] Trial 79 finished with value: 587.8992710982918 and parameters: {'iterations': 664, 'depth': 6, 'learning_rate': 0.19974657722806663, 'l2_leaf_reg': 9.643984551624143, 'subsample': 0.6908436388557593, 'random_strength': 7.186633770673714, 'leaf_estimation_iterations': 3}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:36:56,130] Trial 80 finished with value: 588.7684323677928 and parameters: {'iterations': 519, 'depth': 5, 'learning_rate': 0.09347865716732127, 'l2_leaf_reg': 0.48022424208761927, 'subsample': 0.7305126358359099, 'random_strength': 8.042788539939734, 'leaf_estimation_iterations': 5}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:37:18,088] Trial 81 finished with value: 587.5706932310446 and parameters: {'iterations': 615, 'depth': 7, 'learning_rate': 0.03643073667114153, 'l2_leaf_reg': 1.4992428999378935, 'subsample': 0.7618756629774674, 'random_strength': 6.436880312685535, 'leaf_estimation_iterations': 3}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:37:46,339] Trial 82 finished with value: 588.9695418149964 and parameters: {'iterations': 679, 'depth': 7, 'learning_rate': 0.23671742285870456, 'l2_leaf_reg': 5.907352865637672, 'subsample': 0.7990880667428818, 'random_strength': 6.787436336310423, 'leaf_estimation_iterations': 4}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:38:12,449] Trial 83 finished with value: 587.1974857792276 and parameters: {'iterations': 639, 'depth': 6, 'learning_rate': 0.05198799645630052, 'l2_leaf_reg': 2.4109097352329676, 'subsample': 0.7384753156136511, 'random_strength': 7.7387690209855275, 'leaf_estimation_iterations': 6}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:39:56,714] Trial 84 finished with value: 587.5100533416546 and parameters: {'iterations': 757, 'depth': 10, 'learning_rate': 0.07844611221635958, 'l2_leaf_reg': 1.2581826891462193, 'subsample': 0.7757170444631053, 'random_strength': 7.044751725257809, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:40:17,661] Trial 85 finished with value: 586.413663548669 and parameters: {'iterations': 720, 'depth': 7, 'learning_rate': 0.030801093911339995, 'l2_leaf_reg': 4.752833289829571, 'subsample': 0.7012299538182744, 'random_strength': 6.713589181589612, 'leaf_estimation_iterations': 1}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:40:40,064] Trial 86 finished with value: 586.85604177263 and parameters: {'iterations': 708, 'depth': 7, 'learning_rate': 0.041861434403143535, 'l2_leaf_reg': 3.3217747517497185, 'subsample': 0.632248757032564, 'random_strength': 7.55032483639647, 'leaf_estimation_iterations': 1}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:40:52,669] Trial 87 finished with value: 586.9949290788569 and parameters: {'iterations': 520, 'depth': 6, 'learning_rate': 0.030917700191934697, 'l2_leaf_reg': 0.6392865863886241, 'subsample': 0.7048247342407421, 'random_strength': 5.720650640684925, 'leaf_estimation_iterations': 1}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:41:15,037] Trial 88 finished with value: 586.7246474367867 and parameters: {'iterations': 619, 'depth': 7, 'learning_rate': 0.071875073462215, 'l2_leaf_reg': 5.286107437245436, 'subsample': 0.7454696861633934, 'random_strength': 8.646284453606414, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:41:19,216] Trial 89 finished with value: 587.4739624304237 and parameters: {'iterations': 130, 'depth': 7, 'learning_rate': 0.06025384913703384, 'l2_leaf_reg': 1.855871765046781, 'subsample': 0.6804541500714483, 'random_strength': 7.9118537268420575, 'leaf_estimation_iterations': 1}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:41:54,698] Trial 90 finished with value: 586.2653087332259 and parameters: {'iterations': 727, 'depth': 8, 'learning_rate': 0.01823471126105211, 'l2_leaf_reg': 5.985234471165998, 'subsample': 0.8504867456627171, 'random_strength': 7.368214551094082, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:42:31,548] Trial 91 finished with value: 586.2713567437944 and parameters: {'iterations': 689, 'depth': 8, 'learning_rate': 0.023090364507411955, 'l2_leaf_reg': 6.96143118449214, 'subsample': 0.846843531629844, 'random_strength': 6.940590113168666, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:43:11,258] Trial 92 finished with value: 586.3426279662323 and parameters: {'iterations': 794, 'depth': 8, 'learning_rate': 0.023886638469851514, 'l2_leaf_reg': 5.186352207044926, 'subsample': 0.8486040151319213, 'random_strength': 7.408020294606152, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:43:43,099] Trial 93 finished with value: 585.9856476374956 and parameters: {'iterations': 688, 'depth': 8, 'learning_rate': 0.019496786694499387, 'l2_leaf_reg': 9.66492431780626, 'subsample': 0.872024260241315, 'random_strength': 6.660756883406238, 'leaf_estimation_iterations': 2}. Best is trial 73 with value: 585.9777709307356.
# [I 2024-03-11 14:44:17,326] Trial 94 finished with value: 585.8486719824873 and parameters: {'iterations': 722, 'depth': 8, 'learning_rate': 0.018313719971715867, 'l2_leaf_reg': 9.844878783629667, 'subsample': 0.878973659272283, 'random_strength': 6.071261562341775, 'leaf_estimation_iterations': 2}. Best is trial 94 with value: 585.8486719824873.
# [I 2024-03-11 14:44:54,633] Trial 95 finished with value: 586.3084192214509 and parameters: {'iterations': 796, 'depth': 8, 'learning_rate': 0.019684614643601894, 'l2_leaf_reg': 2.821484116836675, 'subsample': 0.8744696803348228, 'random_strength': 6.07187205692953, 'leaf_estimation_iterations': 2}. Best is trial 94 with value: 585.8486719824873.
# [I 2024-03-11 14:45:27,114] Trial 96 finished with value: 586.532611714708 and parameters: {'iterations': 790, 'depth': 8, 'learning_rate': 0.017800256073751693, 'l2_leaf_reg': 0.9385054750694508, 'subsample': 0.8830228125259455, 'random_strength': 6.019880500109776, 'leaf_estimation_iterations': 1}. Best is trial 94 with value: 585.8486719824873.
# [I 2024-03-11 14:46:05,217] Trial 97 finished with value: 586.8456153373402 and parameters: {'iterations': 807, 'depth': 8, 'learning_rate': 0.025590026430716457, 'l2_leaf_reg': 2.822886817489145, 'subsample': 0.8709162548980331, 'random_strength': 6.368152014583285, 'leaf_estimation_iterations': 2}. Best is trial 94 with value: 585.8486719824873.
# [I 2024-03-11 14:46:51,343] Trial 98 finished with value: 585.8462123757188 and parameters: {'iterations': 724, 'depth': 9, 'learning_rate': 0.020176940667001514, 'l2_leaf_reg': 9.741938710014464, 'subsample': 0.8459663325320136, 'random_strength': 6.657495381980411, 'leaf_estimation_iterations': 1}. Best is trial 98 with value: 585.8462123757188.
# [I 2024-03-11 14:47:30,395] Trial 99 finished with value: 586.4654433016264 and parameters: {'iterations': 829, 'depth': 8, 'learning_rate': 0.01689173194925533, 'l2_leaf_reg': 1.4386521467749782, 'subsample': 0.9289530107320949, 'random_strength': 6.108485893547849, 'leaf_estimation_iterations': 2}. Best is trial 98 with value: 585.8462123757188.
# Best trial: {'iterations': 724, 'depth': 9, 'learning_rate': 0.020176940667001514, 'l2_leaf_reg': 9.741938710014464, 'subsample': 0.8459663325320136, 'random_strength': 6.657495381980411, 'leaf_estimation_iterations': 1}

# %%
# 최종모델
final_model = CatBoostRegressor(**study.best_trial.params)
final_model.fit(X_train, Y_train, verbose=100)
# Out:
# 0:	learn: 697.7983898	total: 18.4ms	remaining: 13.3s
# 100:	learn: 590.6908409	total: 1.24s	remaining: 7.66s
# 200:	learn: 579.2219007	total: 2.41s	remaining: 6.28s
# 300:	learn: 572.9614159	total: 4.85s	remaining: 6.81s
# 400:	learn: 567.7768364	total: 6.63s	remaining: 5.34s
# 500:	learn: 562.4764843	total: 7.82s	remaining: 3.48s
# 600:	learn: 556.5447637	total: 9s	remaining: 1.84s
# 700:	learn: 551.3050198	total: 10.1s	remaining: 333ms
# 723:	learn: 550.4724727	total: 10.4s	remaining: 0us

# %%
# test 데이터에 대해 예측
predictions = final_model.predict(test_data)

# 음수 예측값을 0으로 대체
predictions = np.maximum(0, predictions)

# submission
submission = pd.read_csv('/content/drive/MyDrive/소득 예측/sample_submission.csv')
submission['Income'] = predictions
submission.to_csv('submission_소득예측.csv', index=False)

from google.colab import files
files.download('submission_소득예측.csv')
